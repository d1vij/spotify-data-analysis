# %% [markdown]
# Ip 7/11/2025
# FORMAT OF PROJECT FILE.(hardcopy)
# 1.Title page(designed by you)
# 2.Certificate(school will give)
# 3.Acknowledgement
# 4.Output of the Project
# 5.Source code
# 6.csv files used
# 7.bibliography.
# Thank you
# # Spotify Data Analysis
#
# ## Downloading your own account's listening history
# - Go to your [Spotify Account page](https://www.spotify.com/in-en/account/privacy/), and under `Download your data` section check `Select Extended streaming history` and request data.
#
# - Spotify would then send you a confirmation mail, click confirm and wait for the data to get compiled
#
# ![Confirmation Mail](./images/confirmation.png)
#
# ## Generating your own Analysis
#
# 1. Clone this repo or download the zip and extract it to a folder
#
#
# ```bash
# git clone https://github.com/d1vij/spotify-data-analysis/
# ```
#
# 2. If on unix based environments, run `setup.sh`
# ```bash
# bash setup.sh
# ```
# Else manually create a venv and install `requirements.txt`
#
# 3. Start the jupyter server
# ```bash
# jupyter lab
# ```
# 4. Open and run all cells of this notebook (_project.ipynb_)

# %% [markdown]
# # About the project

# %% [markdown]
# The project involves analysis all the tracks listened on Spotify. (Think of it like a mini Spotify wrapped :))
#
# This project majorly uses pandas for data manipulation and matplotlib and along with seaborn for all the plottings along with a bit of external libraries here and there.
#
# All the helper functions and utilites is made into a unified module `utils` and further description along with its working is explained in each of its corresponding submodules.
#
# All generic plots are present in `utils.plot_sources.plotters` module whereas the functions utilizing them to generate analysis ae present in the `utils.plot_sources.analysis_plots` module

# %% [markdown]
# # Imports and configurations

# %%
import pandas as pd

# Prevent wrapping of dataframes when printed
pd.set_option("display.expand_frame_repr", False)


# Disabling warnings generated by matplotlib
import warnings

warnings.filterwarnings("ignore")


from utils.generate_frame import generate_frame

# Plot imports
from utils.plot_sources.analysis_plots.top_n import top_analysis
from utils.plot_sources.analysis_plots.daily_tracks_graph import daily_tracks_graph
from utils.plot_sources.analysis_plots.daily_listening_activity import (
    daily_listening_activity,
)
from utils.plot_sources.analysis_plots.track_playtime_kde_dist import (
    track_playtime_kde_dist,
)
from utils.plot_sources.analysis_plots.per_artist_analysis import (
    interactive_per_artist_analysis,
    analysis_per_artist,
)

# %%
df = generate_frame()

from os import path
artists_df = pd.read_csv(path.abspath("./ext_data/global_music_artists.csv"))

# %% [markdown]
# ## About the data
# Spotify provides a zip file containing all of listening history split into json files of a max size of around 12KB
#
# ![Manual Unzipping](./images/manual_unzipping.png)
#
# Although this could've been unzipped and processed manually, the script `utils.process_zip` does it automatically for us :P.
#
# The data compilation and dataframe creation steps are as follows
# 1. Asking the user path where the zip file is stored
# 2. Unzipping it, and reading every json file having the name prefix *Streaming_History_Audio_*
#
# Each json file is an array of objects like this
#
# ```json
# {
#     "ts": "2023-04-09T14:24:49Z",
#     "platform": "android",
#     "ms_played": 185733,
#     "conn_country": "IN",
#     "ip_addr": "152.57.221.62",
#     "master_metadata_track_name": "Here Comes The Sun - Remastered 2009",
#     "master_metadata_album_artist_name": "The Beatles",
#     "master_metadata_album_album_name": "Abbey Road",
#     "spotify_track_uri": "spotify:track:6dGnYIeXmHdcikdzNNDMm2",
#     "episode_name": null,
#     "episode_show_name": null,
#     "spotify_episode_uri": null,
#     "audiobook_title": null,
#     "audiobook_uri": null,
#     "audiobook_chapter_uri": null,
#     "audiobook_chapter_title": null,
#     "reason_start": "playbtn",
#     "reason_end": "trackdone",
#     "shuffle": false,
#     "skipped": false,
#     "offline": false,
#     "offline_timestamp": 1681050047,
#     "incognito_mode": false
# }
# ```
# 3. Filtering out only the required data from the whole data object
# So in the end of compilation, a new json file is generated, albeit a big one (around 11MB for my data), containing array of processed data objects
# ```json
# {
#     "ts": "2025-07-10T17:31:04Z",
#     "ms_played": 255080,
#     "master_metadata_track_name": "In Bloom",
#     "master_metadata_album_artist_name": "Nirvana",
#     "master_metadata_album_album_name": "Nevermind"
# }
# ```
# Although spotify provides alot of metrics, (see `utils.TrackInfoClasses.SongAttributes`), I have only used

# %%
df.head(10)
# Out:
#                          ts  ms_played        master_metadata_track_name master_metadata_album_artist_name master_metadata_album_album_name
# 0 2023-06-25 04:54:28+00:00       1454                           L-O-V-E                     Nat King Cole                          L-O-V-E
# 1 2023-06-25 04:57:08+00:00     161560                   Johnny B. Goode                       Chuck Berry                  Berry Is On Top
# 2 2023-06-25 04:59:33+00:00      62277                   Only the Lonely                       Roy Orbison            Sings Lonely and Blue
# 3 2023-06-25 05:17:46+00:00       1568  Under Pressure - Remastered 2011                             Queen                        Hot Space
# 4 2023-06-25 05:41:36+00:00       4390      Satyam Shivam Sundaram-Pt. 1                   Lata Mangeshkar           Satyam Shivam Sundaram
# 5 2023-06-25 05:45:37+00:00     210003               Dekha Ek Khwab - II                   Lata Mangeshkar      Remembering Lata Mangeshkar
# 6 2023-06-25 06:07:42+00:00       6050               Lag Ja Gale Se Phir                   Lata Mangeshkar            Lata Surili Phuljhadi
# 7 2023-06-25 06:12:47+00:00     293333                         Fireflies                       Indus Creed                           Evolve
# 8 2023-06-25 06:14:20+00:00      92176                       Anuva's Sky                   Blackstratblues          Nights in Shining Karma
# 9 2023-06-25 06:14:40+00:00      19790                          Tere Bin                    Rabbi Shergill                            Rabbi

# %%
# Saving to csv
csv = df.head().to_csv()
print(csv)
# Out:
# ,ts,ms_played,master_metadata_track_name,master_metadata_album_artist_name,master_metadata_album_album_name
# 0,2023-06-25 04:54:28+00:00,1454,L-O-V-E,Nat King Cole,L-O-V-E
# 1,2023-06-25 04:57:08+00:00,161560,Johnny B. Goode,Chuck Berry,Berry Is On Top
# 2,2023-06-25 04:59:33+00:00,62277,Only the Lonely,Roy Orbison,Sings Lonely and Blue
# 3,2023-06-25 05:17:46+00:00,1568,Under Pressure - Remastered 2011,Queen,Hot Space
# 4,2023-06-25 05:41:36+00:00,4390,Satyam Shivam Sundaram-Pt. 1,Lata Mangeshkar,Satyam Shivam Sundaram

# %% [markdown]
# ## All the analysis

# %% [markdown]
# ### Top 50 played artists by listening minutes

# %%
top_analysis(df)
# Out:
# Out of 1768 artists, the top 50 artists based on track playtimes are
# The Beatles - 105.9 hours
# Pink Floyd - 89.2 hours
# Pritam - 75.1 hours
# Queen - 67.7 hours
# Eminem - 53.3 hours
# Kishore Kumar - 44.7 hours
# Eagles - 38.8 hours
# David Bowie - 31.1 hours
# Led Zeppelin - 30.5 hours
# Arijit Singh - 28.1 hours
# Michael Jackson - 26.7 hours
# A.R. Rahman - 26.0 hours
# Elton John - 24.4 hours
# Billy Joel - 23.7 hours
# Amit Trivedi - 22.9 hours
# The Rolling Stones - 20.9 hours
# Rocket Man (I Think It's Going To Be A Long, Long Time) - 72 plays
# Out of 6542 unique albums, the top 50 played albums based on approximate playcounts are
# Kasoor - 87.0 plays
# Kesariya - 83.0 plays
# A Different Beat - 80.0 plays
# Kahani (From "Laal Singh Chaddha") - 78.0 plays
# Dard-E-Jigar - 76.0 plays
# Hot Space - 72.0 plays
# Delhi Belly - 72.0 plays
# Rangi Saari - 69.0 plays
# Ajanabee - 62.0 plays
# Doobey - 61.0 plays
# Gangsta's Paradise - 60.0 plays
# Pendulum - 60.0 plays
# Sunoh - 60.0 plays
# The Dark Side of the Moon - 59.0 plays
# Pablo Honey - 59.0 plays
# Pat Garrett & Billy The Kid - 58.0 plays
# 20/20 - 57.0 plays
# Wish You Were Here - 54.0 plays
# Tamasha - 53.0 plays
# Just As I Am - 51.0 plays
# Shor in the City (Original Motion Picture Soundtrack) - 49.0 plays
# Balika Badhu - 48.0 plays
# I Love You...Forever - 48.0 plays
# Kalaakaar (Original Motion Picture Soundtrack) - 47.0 plays
# Oh, Pretty Woman - 47.0 plays
# Ladies And Gentlemen... The Best Of George Michael - 46.0 plays
# Mere Liye Tum Kaafi Ho (From "Shubh Mangal Zyada Saavdhan") - 46.0 plays
# Elephant - 45.0 plays
# Pasoori - 45.0 plays
# Raataan Lambiyan - 45.0 plays
# everything sucks - 42.0 plays
# Just Lose It - 42.0 plays
# Sarfarosh - 40.0 plays
# Sleeping With The Past - 40.0 plays
# FRIENDS - 40.0 plays
# From Elvis in Memphis - 39.0 plays
# Strawberries & Cigarettes - 39.0 plays
# Chaand Baaliyan - 39.0 plays
# Rock Of The Westies - 39.0 plays
# No Secrets - 38.0 plays
# Lootera - 38.0 plays
# Point Of Know Return - 38.0 plays
# Living in the Material World - 37.0 plays
# Dil Na Jaaneya (From "Good Newwz") - 37.0 plays
# Bunty Aur Babli 2 - 37.0 plays
# SugarCrash! - 36.0 plays
# Karthik Calling Karthik - 36.0 plays
# At The Close Of A Century - 36.0 plays
# You're the Inspiration: A Collection - 36.0 plays
# The Game - 36.0 plays

# %%
# Scatter plot
daily_tracks_graph(df)

# %%
# Line plot
daily_listening_activity(df)

# %%
# Line plot
track_playtime_kde_dist(df)

# %% [markdown]
# interactive_per_artist_analysis(df, artists_df)

# %%
from utils.plot_sources.analysis_plots.artist_corelation_plot import (
    generate_correlation_matrix,
    generate_probability_matrix,
)
from utils.plot_sources.plotters.plot_heatmap import plot_heatmap

mat = generate_correlation_matrix(
    df, "master_metadata_album_artist_name", "ms_played", "day"
)
mat = generate_probability_matrix(mat)
plot_heatmap(
    mat,
    "Probability that tracks by two artists were listened on the same day",
    "Artist A",
    "Artist B",
    _fmt=".1f",
)

# %%
def genre_analysis(user_df:pd.DataFrame, artists_df: pd.DataFrame):
    unique_artists_name = user_df["master_metadata_album_artist_name"].unique()
    unique_artists_df = artists_df.loc[
        artists_df["artist_name"].isin(unique_artists_name)
    ]

    unique_genres = {}
    for genre_list in unique_artists_df["artist_genre"]:
        for genre in genre_list.split(","):
            genre = genre.strip()
            unique_genres[genre] = unique_genres.get(genre, 0) + 1

    # Number of artists under a particular genre
    unique_genres_ser = pd.Series(unique_genres)

# %% [markdown]
# You most listened artists from < Country name >
